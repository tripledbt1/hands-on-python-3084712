# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
1 + 1
# Out:
# 2

# %%
from My_Work import envcheck

# %%
import numpy as np, seaborn as sns, matplotlib.pyplot as plt

x = np.random.normal(size=500)
sns.histplot(x, kde=True)
plt.show()
